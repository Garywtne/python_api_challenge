# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy import stats
from scipy.stats import linregress
from citipy import citipy

# Import API key from file
from api_keys import weather_api_key


# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# %%
output_data_file
# Out:
# '../output_data/cities.csv'

# %% [markdown]
# ## Generate Cities List

# %%
# Create empty lists for lattitude and longitude and for city names
lat_lngs = []
cities = []

# define the ranges of lattitude and longitude and save into variables
lat_range = (-90, 90)
lng_range = (-180, 180)

# using numpy generate 1500 randon number combinations within the defined ranges to ensure sufficient to achieve a minimum of 500 
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

# zip the to list together and save into variable lats_lngs
lats_lngs = zip(lats, lngs)

# Loop through the lats_lngs series using the citipy.nearest_city function to find the city_name of the nearest city
for lat_lng in lats_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city_name doesnt already exist then add it to the cities list
    if city not in cities:
        cities.append(city)

# Using the len() function count the number of cities in the list to ensure that it is over 500
len(cities)
# Out:
# 625

# %%
print(cities)
# Out:
# ['mataura', 'gedo', 'deputatskiy', 'cayambe', 'moba', 'hithadhoo', 'kuching', 'mar del plata', 'geraldton', 'barentsburg', 'hualmay', 'acapulco', 'taolanaro', 'bluff', 'sao bento do sul', 'hermanus', 'yellowknife', 'butaritari', 'albany', 'scarborough', 'winona', 'lolua', 'new norfolk', 'punta arenas', 'giyani', 'airai', 'busselton', 'hilo', 'laguna', 'puerto madryn', 'chuy', 'richards bay', 'onguday', 'shahrud', 'olafsvik', 'jamestown', 'adrar', 'georgetown', 'batagay-alyta', 'kapaa', 'bethel', 'buzmeyin', 'port alfred', 'xinqing', 'castro', 'san francisco', 'torbay', 'codrington', 'hobart', 'peniche', 'rikitea', 'muzhi', 'saint george', 'malaya serdoba', 'lusaka', 'kahului', 'shatki', 'ushuaia', 'skalistyy', 'jacqueville', 'tumannyy', 'aksay', 'harper', 'grand river south east', 'illoqqortoormiut', 'safaga', 'svetlyy', 'labuan', 'marcona', 'tubuala', 'bredasdorp', 'alma', 'puerto ayora', 'tiksi', 'atuona', 'cape town', 'mullaitivu', 'macaboboni', 'naze', 'lebu', 'samusu', 'tagusao', 'acari', 'vastervik', 'bandarbeyla', 'kodiak', 'nuuk', 'qaanaaq', 'zhigalovo', 'ponta do sol', 'aklavik', 'vaini', 'poum', 'barrow', 'rolim de moura', 'dikson', 'east london', 'pevek', 'halalo', 'namatanai', 'yirol', 'cherskiy', 'tuktoyaktuk', 'victoria', 'aden', 'utraula', 'saint-philippe', 'primorka', 'tsihombe', 'palabuhanratu', 'markova', 'santa fe', 'khatanga', 'mahebourg', 'madang', 'pucallpa', 'attawapiskat', 'fairbanks', 'wahpeton', 'salalah', 'faanui', 'cidreira', 'ancud', 'lorengau', 'avarua', 'san quintin', 'the valley', 'vestmannaeyjar', 'santa cruz', 'biltine', 'prince albert', 'glace bay', 'bubaque', 'san vicente', 'labrea', 'bukachacha', 'ribeira grande', 'caravelas', 'tasiilaq', 'grindavik', 'kruisfontein', 'samur', 'nanortalik', 'maragogi', 'grand gaube', 'ardistan', 'dawei', 'verkhnetulomskiy', 'banda aceh', 'bagli', 'tanga', 'alofi', 'kondinskoye', 'lanigan', 'praia da vitoria', 'aizpute', 'huarmey', 'lasa', 'mantenopolis', 'port hardy', 'ostrovnoy', 'maria aurora', 'morshansk', 'la ronge', 'cayenne', 'pryozerne', 'buala', 'bababe', 'bograd', 'kang', 'karratha', 'arraial do cabo', 'fukue', 'komsomolskiy', 'santa rosa', 'hunza', 'chokurdakh', 'kindersley', 'hasaki', 'eskasem', 'conceicao do rio verde', 'itaituba', 'conceicao do araguaia', 'saint-paul', 'touros', 'dzhebariki-khaya', 'port elizabeth', 'worthington', 'ilulissat', 'katsuura', 'mutis', 'lahaina', 'payo', 'pemangkat', 'sungaipenuh', 'kingaroy', 'nome', 'hofn', 'shache', 'recarei', 'elbistan', 'ndele', 'xining', 'denpasar', 'port hedland', 'jiblah', 'tura', 'margate', 'mys shmidta', 'sentyabrskiy', 'celestun', 'ambunti', 'nampula', 'saint-augustin', 'baracoa', 'samarai', 'agutaya', 'amderma', 'gornopravdinsk', 'gohpur', 'saskylakh', 'tuatapere', 'hambantota', 'venezuela', 'dali', 'laje', 'garden city', 'rovaniemi', 'hirara', 'priyutnoye', 'cockeysville', 'cabo san lucas', 'upernavik', 'carnarvon', 'kingston', 'edd', 'camargo', 'buchanan', 'nelson bay', 'high rock', 'luangwa', 'vao', 'puerto berrio', 'muroto', 'port keats', 'palmer', 'forestville', 'lima', 'bandar-e lengeh', 'gallup', 'gillette', 'esperance', 'mabaruma', 'kazalinsk', 'eyl', 'rorvik', 'chapais', 'gizo', 'constitucion', 'tommot', 'caohai', 'wonthaggi', 'krasnoselkup', 'bonavista', 'khandyga', 'kokopo', 'ostersund', 'fort nelson', 'castanos', 'waddan', 'severo-kurilsk', 'tukrah', 'port lincoln', 'mercedes', 'vila franca do campo', 'karaul', 'lavrentiya', 'kaduqli', 'fortuna', 'saryg-sep', 'yershov', 'klaksvik', 'artyk', 'kamenskoye', 'williston', 'ostrow mazowiecka', 'benguela', 'kipushi', 'fereydun kenar', 'barcelos', 'narsaq', 'poli', 'saint-leu', 'jackson', 'calvinia', 'noumea', 'baherden', 'nioro', 'nouadhibou', 'norman wells', 'egvekinot', 'solton', 'dunedin', 'pangai', 'rungata', 'kavieng', 'sataua', 'nikolskoye', 'amga', 'clyde river', 'provideniya', 'dafeng', 'urdzhar', 'agua fria', 'ca mau', 'khudumelapye', 'souillac', 'pangnirtung', 'ust-tsilma', 'norsup', 'morwell', 'phirangipuram', 'ahipara', ' ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Create the URL for the Weather Map API Call requesting imperial measurments and adding the api key from my api_keys file

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# # print url to check
print(url)

# create an empty list for the results of the api call
city_data = []
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=36426fe7b8f897a2610ab86f3f9f9741

# %%
len(city_data)
# Out:
# 0

# %%
#Print an opening statement to log each city as it's being processed, with the city number and city name.  
print("Retrieving cities     ")
print("-----------------------------")

# Create counters to track how many api calls have been done 
call_counter = 1
set_counter = 1

# loop through the cities list
for i, city in enumerate(cities):
    
# Grouping the calls in sets of 20
     if (i % 20 == 0 and i >= 20):
         set_counter += 1
         call_counter = 0    

# Create the endpoint URL with each city_name added 
     city_url = url + "&q=" + city
    
# Log and print the url call number and city
     print("Processing call %s of Set %s | %s" % (call_counter, set_counter, city))
         
    # Add 1 to the call counter
     call_counter += 1
        
     # Run an API request for each of the cities, use try/except to ensure that the code continues to run when a city isnt found
     try:
         # retrieve the data as a Json
         city_weather = requests.get(city_url).json()

         # retrieve the lattitude, longitude, max temp, cloudiness, wind speed & humidity plus the country and date. save to variables
         city_lat = city_weather["coord"]["lat"]
         city_lng = city_weather["coord"]["lon"]
         city_max_temp = city_weather["main"]["temp_max"]
         city_humidity = city_weather["main"]["humidity"]
         city_clouds = city_weather["clouds"]["all"]
         city_wind = city_weather["wind"]["speed"]
         city_country = city_weather["sys"]["country"]
         city_date = city_weather["dt"]

         # Append the City information into city_data list
         city_data.append({"City": city, 
                           "Lat": city_lat, 
                           "Lng": city_lng, 
                           "Max Temp": city_max_temp,
                           "Humidity": city_humidity,
                           "Cloudiness": city_clouds,
                           "Wind Speed": city_wind,
                           "Country": city_country,
                           "Date": city_date})

     # print exception statement  
     except:
         print("Unable to retrive weather data. Skip to the next city...")
         pass
# Out:
# Retrieving cities
# -----------------------------
# Processing call 1 of Set 1 | mataura
# Processing call 2 of Set 1 | gedo
# Processing call 3 of Set 1 | deputatskiy
# Processing call 4 of Set 1 | cayambe
# Processing call 5 of Set 1 | moba
# Processing call 6 of Set 1 | hithadhoo
# Processing call 7 of Set 1 | kuching
# Processing call 8 of Set 1 | mar del plata
# Processing call 9 of Set 1 | geraldton
# Processing call 10 of Set 1 | barentsburg
# Unable to retrive weather data. Skip to the next city...
# Processing call 11 of Set 1 | hualmay
# Processing call 12 of Set 1 | acapulco
# Processing call 13 of Set 1 | taolanaro
# Unable to retrive weather data. Skip to the next city...
# Processing call 14 of Set 1 | bluff
# Processing call 15 of Set 1 | sao bento do sul
# Processing call 16 of Set 1 | hermanus
# Processing call 17 of Set 1 | yellowknife
# Processing call 18 of Set 1 | butaritari
# Processing call 19 of Set 1 | albany
# Processing call 20 of Set 1 | scarborough
# Processing call 0 of Set 2 | winona
# Processing call 1 of Set 2 | lolua
# Unable to retrive weather data. Skip to the next city...
# Processing call 2 of Set 2 | new norfolk
# Processing call 3 of Set 2 | punta arenas
# Processing call 4 of Set 2 | giyani
# Processing call 5 of Set 2 | airai
# Processing call 6 of Set 2 | busselton
# Processing call 7 of Set 2 | hilo
# Processing call 8 of Set 2 | laguna
# Processing call 9 of Set 2 | puerto madryn
# Processing call 10 of Set 2 | chuy
# Processing call 11 of Set 2 | richards bay
# Processing call 12 of Set 2 | onguday
# Processing call 13 of Set 2 | shahrud
# Processing call 14 of Set 2 | olafsvik
# Processing call 15 of Set 2 | jamestown
# Processing call 16 of Set 2 | adrar
# Processing call 17 of Set 2 | georgetown
# Processing call 18 of Set 2 | batagay-alyta
# Processing call 19 of Set 2 | kapaa
# Processing call 0 of Set 3 | bethel
# Processing call 1 of Set 3 | buzmeyin
# Processing call 2 of Set 3 | port alfred
# Processing call 3 of Set 3 | xinqing
# Processing call 4 of Set 3 | castro
# Processing call 5 of Set 3 | san francisco
# Processing call 6 of Set 3 | torbay
# Processing call 7 of Set 3 | codrington
# Processing call 8 of Set 3 | hobart
# Processing call 9 of Set 3 | peniche
# Processing call 10 of Set 3 | rikitea
# Processing call 11 of Set 3 | muzhi
# Processing call 12 of Set 3 | saint george
# Processing call 13 of Set 3 | malaya serdoba
# Processing call 14 of Set 3 | lusaka
# Processing call 15 of Set 3 | kahului
# Processing call 16 of Set 3 | shatki
# Processing call 17 of Set 3 | ushuaia
# Processing call 18 of Set 3 | skalistyy
# Unable to retrive weather data. Skip to the next city...
# Processing call 19 of Set 3 | jacqueville
# Processing call 0 of Set 4 | tumannyy
# Unable to retrive weather data. Skip to the next city...
# Processing call 1 of Set 4 | aksay
# Processing call 2 of Set 4 | harper
# Processing call 3 of Set 4 | grand river south east
# Unable to retrive weather data. Skip to the next city...
# Processing call 4 of Set 4 | illoqqortoormiut
# Unable to retrive weather data. Skip to the next city...
# Processing call 5 of Set 4 | safaga
# Processing call 6 of Set 4 | svetlyy
# Processing call 7 of Set 4 | labuan
# Processing call 8 of Set 4 | marcona
# Unable to retrive weather data. Skip to the next city...
# Processing call 9 of Set 4 | tubuala
# Processing call 10 of Set 4 | bredasdorp
# Processing call 11 of Set 4 | alma
# Processing call 12 of Set 4 | puerto ayora
# Processing call 13 of Set 4 | tiksi
# Processing call 14 of Set 4 | atuona
# Processing call 15 of Set 4 | cape town
# Processing call 16 of Set 4 | mullaitivu
# Unable to retrive weather data. Skip to the next city...
# Processing call 17 of Set 4 | macaboboni
# Unable to retrive weather data. Skip to the next city...
# Processing call 18 of Set 4 | naze
# Processing call 19 of Set 4 | lebu
# Processing call 0 of Set 5 | samusu
# Unable to retrive weather data. Skip to the next city...
# Processing call 1 of Set 5 | tagusao
# Processing call 2 of Set 5 | acari
# Processing call 3 of Set 5 | vastervik
# Unable to retrive weather data. Skip to the next city...
# Processing call 4 of Set 5 | bandarbeyla
# Processing call 5 of Set 5 | kodiak
# Processing call 6 of Set 5 | nuuk
# Processing call 7 of Set 5 | qaanaaq
# Processing call 8 of Set 5 | zhigalovo
# Processing call 9 of Set 5 | ponta do sol
# Processing call 10 of Set 5 | aklavik
# Processing call 11 of Set 5 | vaini
# Processing call 12 of Set 5 | poum
# Processing call 13 of Set 5 | barrow
# Processing call 14 of Set 5 | rolim de moura
# Unable to retrive weather data. Skip to the next city...
# Processing call 15 of Set 5 | dikson
# Processing call 16 of Set 5 | east london
# Processing call 17 of Set 5 | pevek
# Processing call 18 of Set 5 | halalo
# Unable to retrive weather data. Skip to the next city...
# Processing call 19 of Set 5 | namatanai
# Processing call 0 of Set 6 | yirol
# Unable to retrive weather data. Skip to the next city...
# Processing call 1 of Set 6 | cherskiy
# Processing call 2 of Set 6 | tuktoyaktuk
# Processing call 3 of Set 6 | victoria
# Processing call 4 of Set 6 | aden
# Processing call 5 of Set 6 | utraula
# Processing call 6 of Set 6 | saint-philippe
# Processing call 7 of Set 6 | primorka
# Processing call 8 of Set 6 | tsihombe
# Unable to retrive weather data. Skip to the next city...
# Processing call 9 of Set 6 | palabuhanratu
# Unable to retrive weather data. Skip to the next city...
# Processing call 10 of Set 6 | markova
# Processing call 11 of Set 6 | santa fe
# Processing call 12 of Set 6 | khatanga
# Processing call 13 of Set 6 | mahebourg
# Processing call 14 of Set 6 | madang
# Processing call 15 of Set 6 | pucallpa
# Processing call 16 of Set 6 | attawapiskat
# Unable to retrive weather data. Skip to the next city...
# Processing call 17 of Set 6 | fairbanks
# Processing call 18 of Set 6 | wahpeton
# Processing call 19 of Set 6 | salalah
# Processing call 0 of Set 7 | faanui
# Processing call 1 of Set 7 | cidreira
# Processing call 2 of Set 7 | ancud
# Processing call 3 of Set 7 | lorengau
# Processing call 4 of Set 7 | avarua
# Processing call 5 of Set 7 | san quintin
# Processing call 6 of Set 7 | the valley
# Processing call 7 of Set 7 | vestmannaeyjar
# Processing call 8 of Set 7 | santa cruz
# Processing call 9 of Set 7 | biltine
# Processing call 10 of Set 7 | prince albert
# Processing call 11 of Set 7 | glace bay
# Processing call 12 of Set 7 | bubaque
# Processing call 13 of Set 7 | san vicente
# Processing call 14 of Set 7 | labrea
# Processing call 15 of Set 7 | bukachacha
# Processing call 16 of Set 7 | ribeira grande
# Processing call 17 of Set 7 | caravelas
# Processing call 18 of Set 7 | tasiilaq
# Processing call 19 of Set 7 | grindavik
# Processing call 0 of Set 8 | kruisfontein
# Processing call 1 of Set 8 | samur
# Processing call 2 of Set 8 | nanortalik
# Processing call 3 of Set 8 | maragogi
# Processing call 4 of Set 8 | grand gaube
# Processing call 5 of Set 8 | ardistan
# Unable to retrive weather data. Skip to the next city...
# Processing call 6 of Set 8 | dawei
# Processing call 7 of Set 8 | verkhnetulomskiy
# Processing call 8 of Set 8 | banda aceh
# Processing call 9 of Set 8 | bagli
# Processing call 10 of Set 8 | tanga
# Processing call 11 of Set 8 | alofi
# Processing call 12 of Set 8 | kondinskoye
# Processing call 13 of Set 8 | lanigan
# Processing call 14 of Set 8 | praia da vitoria
# Processing call 15 of Set 8 | aizpute
# Processing call 16 of Set 8 | huarmey
# Processing call 17 of Set 8 | lasa
# Processing call 18 of Set 8 | mantenopolis
# Processing call 19 of Set 8 | port hardy
# Processing call 0 of Set 9 | ostrovnoy
# Processing call 1 of Set 9 | maria aurora
# Processing call 2 of Set 9 | morshansk
# Processing call 3 of Set 9 | la ronge
# Processing call 4 of Set 9 | cayenne
# Processing call 5 of Set 9 | pryozerne
# Processing call 6 of Set 9 | buala
# Processing call 7 of Set 9 | bababe
# Unable to retrive weather data. Skip to the next city...
# Processing call 8 of Set 9 | bograd
# Processing call 9 of Set 9 | kang
# Processing call 10 of Set 9 | karratha
# Processing call 11 of Set 9 | arraial do cabo
# Processing call 12 of Set 9 | fukue
# Processing call 13 of Set 9 | komsomolskiy
# Processing call 14 of Set 9 | santa rosa
# Processing call 15 of Set 9 | hunza
# Unable to retrive weather data. Skip to the next city...
# Processing call 16 of Set 9 | chokurdakh
# Processing call 17 of Set 9 | kindersley
# Processing call 18 of Set 9 | hasaki
# Processing call 19 of Set 9 | eskasem
# Unable to retrive weather data. Skip to the next city...
# Processing call 0 of Set 10 | conceicao do rio verde
# Processing call 1 of Set 10 | itaituba
# Processing call 2 of Set 10 | conceicao do araguaia
# Processing call 3 of Set 10 | saint-paul
# Processing call 4 of Set 10 | touros
# Processing call 5 of Set 10 | dzhebariki-khaya
# Processing call 6 of Set 10 | port elizabeth
# Processing call 7 of Set 10 | worthington
# Processing call 8 of Set 10 | ilulissat
# Processing call 9 of Set 10 | katsuura
# Processing call 10 of Set 10 | mutis
# Processing call 11 of Set 10 | lahaina
# Processing call 12 of Set 10 | payo
# Processing call 13 of Set 10 | pemangkat
# Processing call 14 of Set 10 | sungaipenuh
# Processing call 15 of Set 10 | kingaroy
# Processing call 16 of Set 10 | nome
# Processing call 17 of Set 10 | hofn
# Processing call 18 of Set 10 | shache
# Processing call 19 of Set 10 | recarei
# Processing call 0 of Set 11 | elbistan
# Processing call 1 of Set 11 | ndele
# Processing call 2 of Set 11 | xining
# Processing call 3 of Set 11 | denpasar
# Processing call 4 of Set 11 | port hedland
# Processing call 5 of Set 11 | jiblah
# Processing call 6 of Set 11 | tura
# Processing call 7 of Set 11 | margate
# Processing call 8 of Set 11 | mys shmidta
# Unable to retrive weather data. Skip to the next city...
# Processing call 9 of Set 11 | sentyabrskiy
# Unable to retrive weather data. Skip to the next city...
# Processing call 10 of Set 11 | celestun
# Processing call 11 of Set 11 | ambunti
# Processing call 12 of Set 11 | nampula
# Processing call 13 of Set 11 | saint-augustin
# Processing call 14 of Set 11 | baracoa
# Processing call 15 of Set 11 | samarai
# Processing call 16 of Set 11 | agutaya
# Processing call 17 of Set 11 | amderma
# Unable to retrive weather data. Skip to the next city...
# Processing call 18 of Set 11 | gornopravdinsk
# Processing call 19 of Set 11 | gohpur
# Processing call 0 of Set 12 | saskylakh
# Processing call 1 of Set 12 | tuatapere
# Processing call 2 of Set 12 | hambantota
# Processing call 3 of Set 12 | venezuela
# Processing call 4 of Set 12 | dali
# Processing call 5 of Set 12 | laje
# Processing call 6 of Set 12 | garden city
# Processing call 7 of Set 12 | rovaniemi
# Processing call 8 of Set 12 | hirara
# Processing call 9 of Set 12 | priyutnoye
# Processing call 10 of Set 12 | cockeysville
# Processing call 11 of Set 12 | cabo san lucas
# Processing call 12 of Set 12 | upernavik
# Processing call 13 of Set 12 | carnarvon
# Processing call 14 of Set 12 | kingston
# Processing call 15 of Set 12 | edd
# Processing call 16 of Set 12 | camargo
# Processing call 17 of Set 12 | buchanan
# Processing call 18 of Set 12 | nelson bay
# Processing call 19 of Set 12 | high rock
# Processing call 0 of Set 13 | luangwa
# Processing call 1 of Set 13 | vao
# Processing call 2 of Set 13 | puerto berrio
# Processing call 3 of Set 13 | muroto
# Processing call 4 of Set 13 | port keats
# Processing call 5 of Set 13 | palmer
# Processing call 6 of Set 13 | forestville
# Processing call 7 of Set 13 | lima
# Processing call 8 of Set 13 | bandar-e lengeh
# Processing call 9 of Set 13 | gallup
# Processing call 10 of Set 13 | gillette
# Processing call 11 of Set 13 | esperance
# Processing call 12 of Set 13 | mabaruma
# Processing call 13 of Set 13 | kazalinsk
# Unable to retrive weather data. Skip to the next city...
# Processing call 14 of Set 13 | eyl
# Processing call 15 of Set 13 | rorvik
# Processing call 16 of Set 13 | chapais
# Processing call 17 of Set 13 | gizo
# Processing call 18 of Set 13 | constitucion
# Processing call 19 of Set 13 | tommot
# Processing call 0 of Set 14 | caohai
# Processing call 1 of Set 14 | wonthaggi
# Processing call 2 of Set 14 | krasnoselkup
# Processing call 3 of Set 14 | bonavista
# Processing call 4 of Set 14 | khandyga
# Processing call 5 of Set 14 | kokopo
# Processing call 6 of Set 14 | ostersund
# Processing call 7 of Set 14 | fort nelson
# Processing call 8 of Set 14 | castanos
# Processing call 9 of Set 14 | waddan
# Processing call 10 of Set 14 | severo-kurilsk
# Processing call 11 of Set 14 | tukrah
# Processing call 12 of Set 14 | port lincoln
# Processing call 13 of Set 14 | mercedes
# Processing call 14 of Set 14 | vila franca do campo
# Processing call 15 of Set 14 | karaul
# Unable to retrive weather data. Skip to the next city...
# Processing call 16 of Set 14 | lavrentiya
# Processing call 17 of Set 14 | kaduqli
# Processing call 18 of Set 14 | fortuna
# Processing call 19 of Set 14 | saryg-sep
# Processing call 0 of Set 15 | yershov
# Processing call 1 of Set 15 | klaksvik
# Processing call 2 of Set 15 | artyk
# Unable to retrive weather data. Skip to the next city...
# Processing call 3 of Set 15 | kamenskoye
# Unable to retrive weather data. Skip to the next city...
# Processing call 4 of Set 15 | williston
# Processing call 5 of Set 15 | ostrow mazowiecka
# Processing call 6 of Set 15 | benguela
# Processing call 7 of Set 15 | kipushi
# Processing call 8 of Set 15 | fereydun kenar
# Processing call 9 of Set 15 | barcelos
# Processing call 10 of Set 15 | narsaq
# Processing call 11 of Set 15 | poli
# Processing call 12 of Set 15 | saint-leu
# Processing call 13 of Set 15 | jackson
# Processing call 14 of Set 15 | calvinia
# Processing call 15 of Set 15 | noumea
# Processing call 16 of Set 15 | baherden
# Processing call 17 of Set 15 | nioro
# Processing call 18 of Set 15 | nouadhibou
# Processing call 19 of Set 15 | norman wells
# Processing call 0 of Set 16 | egvekinot
# Processing call 1 of Set 16 | solton
# Processing call 2 of Set 16 | dunedin
# Processing call 3 of Set 16 | pangai
# Processing call 4 of Set 16 | rungata
# Unable to retrive weather data. Skip to the next city...
# Processing call 5 of Set 16 | kavieng
# Processing call 6 of Set 16 | sataua
# Unable to retrive weather data. Skip to the next city...
# Processing call 7 of Set 16 | nikolskoye
# Processing call 8 of Set 16 | amga
# Processing call 9 of Set 16 | clyde river
# Processing call 10 of Set 16 | provideniya
# Processing call 11 of Set 16 | dafeng
# Processing call 12 of Set 16 | urdzhar
# Unable to retrive weather data. Skip to the next city...
# Processing call 13 of Set 16 | agua fria
# Processing call 14 of Set 16 | ca mau
# Processing call 15 of Set 16 | khudumelapye
# Processing call 16 of Set 16 | souillac
# Processing call 17 of Set 16 | pangnirtung
# Processing call 18 of Set 16 | ust-tsilma
# Processing call 19 of Set 16 | norsup
# Processing call 0 of Set 17 | morwell
# Processing call 1 of Set 17 | phirangipuram
# Processing call 2 of Set 17 | ahipara
# Processing call 3 of Set 17 | abrau-dyurso
# Processing call 4 of Set 17 | gushikawa
# Processing call 5 of Set 17 | lompoc
# Processing call 6 of Set 17 | hervey bay
# Processing call 7 of Set 17 | temaraia
# Unable to retrive weather data. Skip to the next city...
# Processing call 8 of Set 17 | porosozero
# Processing call 9 of Set 17 | coihaique
# Processing call 10 of Set 17 | doctor pedro p. pena
# Unable to retrive weather data. Skip to the next city...
# Processing call 11 of Set 17 | port pirie
# Processing call 12 of Set 17 | jardim
# Processing call 13 of Set 17 | dudinka
# Processing call 14 of Set 17 | bambous virieux
# Processing call 15 of Set 17 | russkaya polyana
# Processing call 16 of Set 17 | mandalgovi
# Processing call 17 of Set 17 | kikwit
# Processing call 18 of Set 17 | westport
# Processing call 19 of Set 17 | stephenville
# Processing call 0 of Set 18 | vestmanna
# Processing call 1 of Set 18 | cazones
# Processing call 2 of Set 18 | liyang
# Processing call 3 of Set 18 | talaja
# Processing call 4 of Set 18 | honiara
# Processing call 5 of Set 18 | pisco
# Processing call 6 of Set 18 | puerto leguizamo
# Processing call 7 of Set 18 | isangel
# Processing call 8 of Set 18 | ketchikan
# Processing call 9 of Set 18 | atascocita
# Processing call 10 of Set 18 | roma
# Processing call 11 of Set 18 | coahuayana
# Processing call 12 of Set 18 | berlevag
# Processing call 13 of Set 18 | coari
# Processing call 14 of Set 18 | daru
# Processing call 15 of Set 18 | kichera
# Processing call 16 of Set 18 | martapura
# Processing call 17 of Set 18 | zverinogolovskoye
# Processing call 18 of Set 18 | sechura
# Processing call 19 of Set 18 | haibowan
# Unable to retrive weather data. Skip to the next city...
# Processing call 0 of Set 19 | korla
# Processing call 1 of Set 19 | thompson
# Processing call 2 of Set 19 | achisay
# Unable to retrive weather data. Skip to the next city...
# Processing call 3 of Set 19 | surovikino
# Processing call 4 of Set 19 | cehegin
# Processing call 5 of Set 19 | dicabisagan
# Processing call 6 of Set 19 | college
# Processing call 7 of Set 19 | nur
# Processing call 8 of Set 19 | port hawkesbury
# Processing call 9 of Set 19 | ongandjera
# Processing call 10 of Set 19 | bambanglipuro
# Processing call 11 of Set 19 | avera
# Processing call 12 of Set 19 | lixourion
# Processing call 13 of Set 19 | taseyevo
# Processing call 14 of Set 19 | portland
# Processing call 15 of Set 19 | trelleborg
# Processing call 16 of Set 19 | pinotepa nacional
# Processing call 17 of Set 19 | wairoa
# Processing call 18 of Set 19 | yaan
# Processing call 19 of Set 19 | sao filipe
# Processing call 0 of Set 20 | luderitz
# Processing call 1 of Set 20 | labuhan
# Processing call 2 of Set 20 | dakar
# Processing call 3 of Set 20 | sitka
# Processing call 4 of Set 20 | kaitangata
# Processing call 5 of Set 20 | brae
# Processing call 6 of Set 20 | kitimat
# Processing call 7 of Set 20 | balimo
# Unable to retrive weather data. Skip to the next city...
# Processing call 8 of Set 20 | ambon
# Processing call 9 of Set 20 | dien bien
# Unable to retrive weather data. Skip to the next city...
# Processing call 10 of Set 20 | kroonstad
# Processing call 11 of Set 20 | taree
# Processing call 12 of Set 20 | camacha
# Processing call 13 of Set 20 | suleja
# Processing call 14 of Set 20 | van
# Processing call 15 of Set 20 | san ciro de acosta
# Processing call 16 of Set 20 | kloulklubed
# Processing call 17 of Set 20 | springbok
# Processing call 18 of Set 20 | seoul
# Processing call 19 of Set 20 | tanout
# Processing call 0 of Set 21 | abnub
# Processing call 1 of Set 21 | katherine
# Processing call 2 of Set 21 | tupik
# Processing call 3 of Set 21 | mount pleasant
# Processing call 4 of Set 21 | kenitra
# Processing call 5 of Set 21 | tidore
# Unable to retrive weather data. Skip to the next city...
# Processing call 6 of Set 21 | rabo de peixe
# Processing call 7 of Set 21 | karamea
# Unable to retrive weather data. Skip to the next city...
# Processing call 8 of Set 21 | kropotkin
# Processing call 9 of Set 21 | yerbogachen
# Processing call 10 of Set 21 | bataipora
# Processing call 11 of Set 21 | danilov
# Processing call 12 of Set 21 | orchard homes
# Processing call 13 of Set 21 | san cristobal
# Processing call 14 of Set 21 | carutapera
# Processing call 15 of Set 21 | sur
# Processing call 16 of Set 21 | lamar
# Processing call 17 of Set 21 | makokou
# Processing call 18 of Set 21 | coquimbo
# Processing call 19 of Set 21 | asayita
# Unable to retrive weather data. Skip to the next city...
# Processing call 0 of Set 22 | babstovo
# Processing call 1 of Set 22 | balkhash
# Processing call 2 of Set 22 | taoudenni
# Processing call 3 of Set 22 | berdigestyakh
# Processing call 4 of Set 22 | valparaiso
# Processing call 5 of Set 22 | viedma
# Processing call 6 of Set 22 | tessalit
# Processing call 7 of Set 22 | decatur
# Processing call 8 of Set 22 | anju
# Processing call 9 of Set 22 | longkou
# Processing call 10 of Set 22 | kavaratti
# Processing call 11 of Set 22 | kiruna
# Processing call 12 of Set 22 | petropavlovsk-kamchatskiy
# Processing call 13 of Set 22 | zhezkazgan
# Processing call 14 of Set 22 | tutoia
# Processing call 15 of Set 22 | lata
# Processing call 16 of Set 22 | cavaillon
# Processing call 17 of Set 22 | nantucket
# Processing call 18 of Set 22 | san policarpo
# Processing call 19 of Set 22 | guliston
# Processing call 0 of Set 23 | benghazi
# Processing call 1 of Set 23 | atbasar
# Processing call 2 of Set 23 | vaitupu
# Unable to retrive weather data. Skip to the next city...
# Processing call 3 of Set 23 | morgantown
# Processing call 4 of Set 23 | vuktyl
# Processing call 5 of Set 23 | saint-georges
# Processing call 6 of Set 23 | taldan
# Processing call 7 of Set 23 | lithgow
# Processing call 8 of Set 23 | hirado
# Processing call 9 of Set 23 | mitchelstown
# Processing call 10 of Set 23 | mujiayingzi
# Processing call 11 of Set 23 | vicuna
# Processing call 12 of Set 23 | ponta delgada
# Processing call 13 of Set 23 | mecca
# Processing call 14 of Set 23 | ust-kamchatsk
# Unable to retrive weather data. Skip to the next city...
# Processing call 15 of Set 23 | mahibadhoo
# Processing call 16 of Set 23 | sumenep
# Processing call 17 of Set 23 | ximei
# Processing call 18 of Set 23 | karpathos
# Processing call 19 of Set 23 | koson
# Processing call 0 of Set 24 | bengkulu
# Processing call 1 of Set 24 | san antonio del tequendama
# Processing call 2 of Set 24 | aykhal
# Processing call 3 of Set 24 | gusau
# Processing call 4 of Set 24 | ozark
# Processing call 5 of Set 24 | padang
# Processing call 6 of Set 24 | yambio
# Processing call 7 of Set 24 | kuche
# Unable to retrive weather data. Skip to the next city...
# Processing call 8 of Set 24 | dalby
# Processing call 9 of Set 24 | cockburn town
# Processing call 10 of Set 24 | laurel
# Processing call 11 of Set 24 | marawi
# Processing call 12 of Set 24 | stoyba
# Unable to retrive weather data. Skip to the next city...
# Processing call 13 of Set 24 | meulaboh
# Processing call 14 of Set 24 | samana
# Processing call 15 of Set 24 | malnas
# Processing call 16 of Set 24 | mehamn
# Processing call 17 of Set 24 | tabarqah
# Unable to retrive weather data. Skip to the next city...
# Processing call 18 of Set 24 | longyearbyen
# Processing call 19 of Set 24 | wejherowo
# Processing call 0 of Set 25 | kidal
# Processing call 1 of Set 25 | aksarka
# Processing call 2 of Set 25 | nicolas bravo
# Processing call 3 of Set 25 | vila velha
# Processing call 4 of Set 25 | oriximina
# Processing call 5 of Set 25 | new glasgow
# Processing call 6 of Set 25 | sarkand
# Processing call 7 of Set 25 | cabedelo
# Processing call 8 of Set 25 | manturovo
# Processing call 9 of Set 25 | mpika
# Processing call 10 of Set 25 | liverpool
# Processing call 11 of Set 25 | ylojarvi
# Processing call 12 of Set 25 | bashtanka
# Processing call 13 of Set 25 | granadilla de abona
# Processing call 14 of Set 25 | champerico
# Processing call 15 of Set 25 | nizhneyansk
# Unable to retrive weather data. Skip to the next city...
# Processing call 16 of Set 25 | mayo
# Processing call 17 of Set 25 | hobyo
# Processing call 18 of Set 25 | luanda
# Processing call 19 of Set 25 | biak
# Processing call 0 of Set 26 | sola
# Processing call 1 of Set 26 | fomboni
# Processing call 2 of Set 26 | polson
# Processing call 3 of Set 26 | yar-sale
# Processing call 4 of Set 26 | puerto escondido
# Processing call 5 of Set 26 | anadyr
# Processing call 6 of Set 26 | darnah
# Processing call 7 of Set 26 | malwan
# Unable to retrive weather data. Skip to the next city...
# Processing call 8 of Set 26 | saint-francois
# Processing call 9 of Set 26 | hay river
# Processing call 10 of Set 26 | shieli
# Processing call 11 of Set 26 | salinopolis
# Processing call 12 of Set 26 | charters towers
# Processing call 13 of Set 26 | karatau
# Processing call 14 of Set 26 | burgeo
# Processing call 15 of Set 26 | iqaluit
# Processing call 16 of Set 26 | umm kaddadah
# Processing call 17 of Set 26 | diffa
# Processing call 18 of Set 26 | kinsale
# Processing call 19 of Set 26 | yamasaki
# Processing call 0 of Set 27 | vostok
# Processing call 1 of Set 27 | lexington
# Processing call 2 of Set 27 | nizhniy odes
# Processing call 3 of Set 27 | wana
# Processing call 4 of Set 27 | babanusah
# Unable to retrive weather data. Skip to the next city...
# Processing call 5 of Set 27 | leshukonskoye
# Processing call 6 of Set 27 | puerto el triunfo
# Processing call 7 of Set 27 | shitanjing
# Processing call 8 of Set 27 | grong
# Processing call 9 of Set 27 | verkhnyaya inta
# Processing call 10 of Set 27 | raga
# Processing call 11 of Set 27 | adre
# Processing call 12 of Set 27 | tarsus
# Processing call 13 of Set 27 | swan hill
# Processing call 14 of Set 27 | teya
# Processing call 15 of Set 27 | axim
# Processing call 16 of Set 27 | hamilton
# Processing call 17 of Set 27 | sai buri
# Processing call 18 of Set 27 | emerald
# Processing call 19 of Set 27 | marzuq
# Processing call 0 of Set 28 | sinkat
# Unable to retrive weather data. Skip to the next city...
# Processing call 1 of Set 28 | warqla
# Unable to retrive weather data. Skip to the next city...
# Processing call 2 of Set 28 | praia
# Processing call 3 of Set 28 | broome
# Processing call 4 of Set 28 | ishigaki
# Processing call 5 of Set 28 | balaipungut
# Processing call 6 of Set 28 | sandakan
# Processing call 7 of Set 28 | heihe
# Processing call 8 of Set 28 | wulanhaote
# Unable to retrive weather data. Skip to the next city...
# Processing call 9 of Set 28 | mahon
# Processing call 10 of Set 28 | talara
# Processing call 11 of Set 28 | ixtapa
# Processing call 12 of Set 28 | stepnyak
# Processing call 13 of Set 28 | talas
# Processing call 14 of Set 28 | japura
# Processing call 15 of Set 28 | henties bay
# Processing call 16 of Set 28 | walvis bay
# Processing call 17 of Set 28 | kandrian
# Processing call 18 of Set 28 | namibe
# Processing call 19 of Set 28 | krasnyy yar
# Processing call 0 of Set 29 | arlit
# Processing call 1 of Set 29 | ziarat
# Processing call 2 of Set 29 | salta
# Processing call 3 of Set 29 | sisimiut
# Processing call 4 of Set 29 | muros
# Processing call 5 of Set 29 | jiddah
# Unable to retrive weather data. Skip to the next city...
# Processing call 6 of Set 29 | aparecida do taboado
# Processing call 7 of Set 29 | ardabil
# Processing call 8 of Set 29 | marsh harbour
# Processing call 9 of Set 29 | ambilobe
# Processing call 10 of Set 29 | strelka
# Processing call 11 of Set 29 | spittal
# Processing call 12 of Set 29 | poya
# Processing call 13 of Set 29 | chumikan
# Processing call 14 of Set 29 | alirajpur
# Processing call 15 of Set 29 | minab
# Processing call 16 of Set 29 | vaitape
# Processing call 17 of Set 29 | ossora
# Processing call 18 of Set 29 | sioux lookout
# Processing call 19 of Set 29 | imbituba
# Processing call 0 of Set 30 | orcopampa
# Processing call 1 of Set 30 | doka
# Processing call 2 of Set 30 | suhbaatar
# Processing call 3 of Set 30 | yumen
# Processing call 4 of Set 30 | waipawa
# Processing call 5 of Set 30 | kota tinggi
# Processing call 6 of Set 30 | rodez
# Processing call 7 of Set 30 | guerande
# Processing call 8 of Set 30 | jiazi
# Processing call 9 of Set 30 | kokorevka
# Processing call 10 of Set 30 | jetpur
# Processing call 11 of Set 30 | quatre cocos
# Processing call 12 of Set 30 | dasoguz
# Processing call 13 of Set 30 | aspe
# Processing call 14 of Set 30 | port blair
# Processing call 15 of Set 30 | ures
# Processing call 16 of Set 30 | belushya guba
# Unable to retrive weather data. Skip to the next city...
# Processing call 17 of Set 30 | durazno
# Processing call 18 of Set 30 | workington
# Processing call 19 of Set 30 | beloha
# Processing call 0 of Set 31 | pandan
# Processing call 1 of Set 31 | zhigansk
# Processing call 2 of Set 31 | tautira
# Processing call 3 of Set 31 | sao joao da barra
# Processing call 4 of Set 31 | kyra
# Processing call 5 of Set 31 | maceio
# Processing call 6 of Set 31 | moissac
# Processing call 7 of Set 31 | calbuco
# Processing call 8 of Set 31 | tambun
# Processing call 9 of Set 31 | port moresby
# Processing call 10 of Set 31 | bucerias
# Processing call 11 of Set 31 | winnemucca
# Processing call 12 of Set 31 | acajutla
# Processing call 13 of Set 31 | mallaig
# Processing call 14 of Set 31 | kysyl-syr
# Processing call 15 of Set 31 | diapaga
# Processing call 16 of Set 31 | ruteng
# Processing call 17 of Set 31 | nhulunbuy
# Processing call 18 of Set 31 | comodoro rivadavia
# Processing call 19 of Set 31 | karlskoga
# Processing call 0 of Set 32 | saint marys
# Processing call 1 of Set 32 | cuauhtemoc
# Processing call 2 of Set 32 | khani
# Processing call 3 of Set 32 | keti bandar
# Processing call 4 of Set 32 | malmyzh

# %%
# Check the length of the city_data list to ensure that it is over 500
len(city_data)
# Out:
# 571

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert the city_data array into a Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# City          571
# Lat           571
# Lng           571
# Max Temp      571
# Humidity      571
# Cloudiness    571
# Wind Speed    571
# Country       571
# Date          571
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      mataura -46.1927  168.8643     49.37        86          66        5.23
# 1         gedo   9.0167   37.4500     80.37        16          20        5.44
# 2  deputatskiy  69.3000  139.9000    -11.36       100         100        3.06
# 3      cayambe   0.0500  -78.1333     49.26        86         100        3.11
# 4         moba  33.2288  105.0179     58.37        56          48        4.79
#
#   Country        Date
# 0      NZ  1649507113
# 1      ET  1649507113
# 2      RU  1649507113
# 3      EC  1649507113
# 4      CN  1649507113

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Display the statistical values 
city_data_pd.describe()
# There are no cities in the data with humidity over 100
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  571.000000  571.000000  571.000000  571.000000  571.000000  571.000000
# mean    20.529539   17.685572   60.381278   69.570928   60.458844    8.487583
# std     32.829533   90.101900   24.298276   23.977324   37.627626    5.993667
# min    -54.800000 -179.166700  -24.470000    1.000000    0.000000    0.000000
# 25%     -6.998900  -63.154050   43.895000   57.000000   20.500000    3.935000
# 50%     24.144700   22.787600   66.130000   77.000000   75.000000    7.230000
# 75%     47.680100  100.344850   78.710000   87.000000   98.000000   11.500000
# max     78.218600  177.483300  107.400000  100.000000  100.000000   29.910000
#
#                Date
# count  5.710000e+02
# mean   1.649507e+09
# std    5.544203e+01
# min    1.649507e+09
# 25%    1.649507e+09
# 50%    1.649507e+09
# 75%    1.649507e+09
# max    1.649507e+09

# %%
# Extract relevant fields from the data frame
lats = city_data_pd["Lat"]
max_temps = city_data_pd["Max Temp"]
humidity = city_data_pd["Humidity"]
cloudiness = city_data_pd["Cloudiness"]
wind_speed = city_data_pd["Wind Speed"]

# Export the City_Data into a csv
city_data_pd.to_csv(output_data_file, index_label="City_ID")
city_data_pd
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        mataura -46.1927  168.8643     49.37        86          66
# 1           gedo   9.0167   37.4500     80.37        16          20
# 2    deputatskiy  69.3000  139.9000    -11.36       100         100
# 3        cayambe   0.0500  -78.1333     49.26        86         100
# 4           moba  33.2288  105.0179     58.37        56          48
# ..           ...      ...       ...       ...       ...         ...
# 566  saint marys  30.7305  -81.5465     55.02        70           0
# 567   cuauhtemoc  28.4167 -106.8667     49.03        33         100
# 568        khani  41.9563   42.9566     51.37        93          99
# 569  keti bandar  24.1447   67.4497     86.49        55          47
# 570      malmyzh  56.5205   50.6818     41.23        97         100
#
#      Wind Speed Country        Date
# 0          5.23      NZ  1649507113
# 1          5.44      ET  1649507113
# 2          3.06      RU  1649507113
# 3          3.11      EC  1649507113
# 4          4.79      CN  1649507113
# ..          ...     ...         ...
# 566        5.75      US  1649507173
# 567        2.21      MX  1649507173
# 568        2.01      GE  1649507173
# 569       15.95      PK  1649507173
# 570       10.20      RU  1649507173
#
# [571 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = city_data_pd['Lat']
y_values = city_data_pd['Max Temp']
plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.show()

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(lats, 
            max_temps,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Latitude vs. Temperature Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Latitude vs. Humidity Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Latitude vs. Cloudiness Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="black", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/Latitude vs. Wind Speed Plot.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept
print(regress_values)
# Out:
# 0      91.394187
# 1      65.732517
# 2      37.712466
# 3      69.900295
# 4      54.478583
#          ...
# 566    55.639808
# 567    56.715277
# 568    50.421987
# 569    58.700929
# 570    43.652457
# Name: Lat, Length: 571, dtype: float64

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.46x +69.92

# %%
# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.39438674240865024

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp',(6,0))
# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.7319949249583384

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 85))
# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.5169146784360652

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity',(45,5))
# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.11741982288175717

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, 'Humidity', (-55, 15))
# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.002688191110572098

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (45,50))
# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.027738402307412483

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, 'Cloudiness', (-55,15))
# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.10562740675716271

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (5,30))
# Save the figure
plt.savefig("../output_data/Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.013244038275075302

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, 'Wind Speed', (-55, 26))
# Save the figure
plt.savefig("../output_data/Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression.png")
# Out:
# The r-value is: 0.0470729932569037
